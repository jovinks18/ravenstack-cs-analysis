# %%
import os
print("Current working dir:", os.getcwd())
print("Files here:", os.listdir('.'))
print("Parent:", os.listdir('..'))
# Out:
# Current working dir: /Users/jovin/cs-churn-project/analysis/analysis
# Files here: ['02_dashboard.ipynb']
# Parent: ['analysis', '01_explore.ipynb']
